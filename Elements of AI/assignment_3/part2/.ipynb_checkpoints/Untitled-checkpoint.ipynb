# %%
#!/usr/local/bin/python3
# CSCI B551 Fall 2019
#
# Authors: Shreyas Bhujbal
#
# based on skeleton code by D. Crandall, 11/2019
#
# ./break_code.py : attack encryption
#


import random
import math
import copy 
import sys
import encode
from random import randint
import math
import numpy as np

def init_table():
    list_alpha = []
    table = {}
    
    for i in range(97, 123):
        list_alpha.append(chr(i))
    # print(list_alpha)
    
    # random.seed(10)
    # random.shuffle(list_alpha)
    
    # print(list_alpha)
    
    for i in range(97, 123):
        character = chr(i)
        table[character] = list_alpha[i-97]
    print(table)
    print('init_done')
    return table

def cal_W0(corp, letter):
    sample = 0
    start_letter = 0
    for word in corp:
        sample = sample+1
        if word[0] == letter:
            start_letter = start_letter + 1
    print('W0: ', letter, ' ', start_letter/sample)
    return start_letter/sample

def cal_Wi(corp, letter1, letter2):
    #p(letter1 | letter2 )
    numerator = 0
    denominator = 0
    for word in corp:
        for i in range(len(word) - 1):
            if word[i] == letter1 and word[i+1] == letter2:
                numerator = numerator + 1
                # print(numerator)
            if word[i] == letter1 :
                denominator = denominator + 1
                # print(denominator)
    if denominator == 0:
        print('Wi: letter1: ', letter1, 'letter2: ', letter2, ' ', denominator)
        return 0

    print('Wi: letter1: ', letter1, 'letter2: ', letter2, ' ', numerator/denominator)
    return numerator/denominator

def cal_all_probs(corpus):
    probs = {}
    print('calculating probability')
    for i in range(97, 123):
        for j in range(97, 123):
            probs[chr(i) + chr(j)] = cal_Wi(corpus, chr(i), chr(j))
    for k in range(97,123):
        probs[chr(k)] = cal_W0(corpus, chr(k))
    return probs
        
def change_config(table, rearrange_tab):
    
    flag = random.randint(0,1) 
    temp = ''
    tmp = {}
    if flag:
        ind = random.randint(0,2)
        tmp = rearrange_tab[ind]
        rearrange_tab[ind] = rearrange_tab[ind+1]
        rearrange_tab[ind+1] = tmp
    else:
        rn = random.randint(97, 121)
        temp = table[chr(rn)]
        table[chr(rn)] = table[chr(rn+1)]
        table[chr(rn+1)] = temp
    return [table, rearrange_tab]

# put your code here!

# if __name__== "__main__":
#     if(len(sys.argv) != 4):
#         raise Exception("usage: ./break_code.py coded-file corpus output-file")

# %%
def break_code(string, corpus, probs):
    # use encode function, change either table or rearrange list
    
    rearrange_tab = [0,1,2,3]
    random.shuffle(rearrange_tab)
    table = init_table()    
    counter = 0
    flag = 0
    text = string.split()
    corp = corpus.split()
    p = 0
    x = 0
    p_prev = float('-Inf')
    table_prev = {}
    rearrange_tab_prev = []

    break_flag = 0
    
    while(counter < 100000):
        counter = counter + 1
        # print(counter)
        new_text = encode.encode(string, table, rearrange_tab)
        
        # if p>math.log10(1+0.5) and p != float('Inf'):
        #     return new_text
        
        if(counter > 79998):
            return new_text
        
        new_text = new_text.split()
        p = 0
        for word in new_text:
            if len(word) == 1:
                # print(probs[word])
                if probs[word]:
                    x = probs[word]
                    p = p + math.log10(x)
                # else:
                #     p = p+0
                #     table, rearrange_tab = change_config(table, rearrange_tab)
                #     break
                    
            else:
                for i in range(len(word)):
                    if(not i):
                        # print(probs[word[0]])
                        if probs[word[0]]:
                            x = probs[word[0]]
                            p = p + math.log10(x)

                        # else:
                        #     p = p+0
                            # break_flag = 1
                            # break
                    
                    else:
                        # print(probs[word[i-1]+word[i]])
                        if probs[word[i-1]+word[i]]:
                            x = probs[word[i-1]+word[i]]
                            p = p + math.log10(1+x)
                        # else:
                        #     p = p + 0
                            # break_flag = 1
                        #     break

            # if p == float('Inf') or break_flag == 1:
            #     table, rearrange_tab = change_config(table, rearrange_tab)
            #     break_flag = 0
            #     # print('==================================')
            #     # print('break')
            #     # print('==================================')
            #     break



#         if p > p_prev:
#             print('---------')
#             print('probab: ', p, 'pprev: ', p_prev, 'counter ', counter)
#             print('---------')

#             print('******** Improved ************')
#             table_prev = table
#             rearrange_tab_prev = rearrange_tab
#             p_prev = p
#             table, rearrange_tab = change_config(table_prev, rearrange_tab_prev)

        
        # if p < p_prev:
        #     print('---------')
        #     print('probab: ', p, 'pprev: ', p_prev)
        #     print('---------')
        #     sc = np.exp(p_prev - p)
        #     print('******** Not Improved ************')
        #     table = table_prev
        #     rearrange_tab = rearrange_tab_prev
        #     p = p_prev
        #     table, rearrange_tab = change_config(table, rearrange_tab)
        
        sc = np.exp(p - p_prev)
        prob = sc if sc <= 1 else 1
        if prob > random.uniform(0,1):
            print(p)
            table_prev = table
            rearrange_tab_prev = rearrange_tab
            p_prev = p    
        table, rearrange_tab = change_config(table_prev, rearrange_tab_prev)

# %%
encoded = encode.read_clean_file('encrypted-text-3.txt')
corpus = encode.read_clean_file('corpus.txt')

# %%
len(corpus.split())

# %%
probs = cal_all_probs(corpus.split())
# Out:
# calculating probability
# Wi: letter1:  a letter2:  a   1.9753008383176757e-05
# Wi: letter1:  a letter2:  b   0.024635952055498053
# Wi: letter1:  a letter2:  c   0.048596351224291456
# Wi: letter1:  a letter2:  d   0.044195380956519675
# Wi: letter1:  a letter2:  e   0.0005767878447887613
# Wi: letter1:  a letter2:  f   0.006881948120698782
# Wi: letter1:  a letter2:  g   0.022016703143888813
# Wi: letter1:  a letter2:  h   0.00041876377772334726
# Wi: letter1:  a letter2:  i   0.03700923650671997
# Wi: letter1:  a letter2:  j   0.00118122990131397
# Wi: letter1:  a letter2:  k   0.011733286979606994
# Wi: letter1:  a letter2:  l   0.11027314459992257
# Wi: letter1:  a letter2:  m   0.02616878550603257
# Wi: letter1:  a letter2:  n   0.2033098140846851
# Wi: letter1:  a letter2:  o   0.00022518429556821505
# Wi: letter1:  a letter2:  p   0.019057702488088937
# Wi: letter1:  a letter2:  q   0.00010271564359251914
# Wi: letter1:  a letter2:  r   0.1114938805180029
# Wi: letter1:  a letter2:  s   0.10271959419419578
# Wi: letter1:  a letter2:  t   0.16010208354732425
# Wi: letter1:  a letter2:  u   0.010421687222964058
# Wi: letter1:  a letter2:  v   0.023383611324004645
# Wi: letter1:  a letter2:  w   0.006392073512795999
# Wi: letter1:  a letter2:  x   0.002326904387538222
# Wi: letter1:  a letter2:  y   0.025398418179088677
# Wi: letter1:  a letter2:  z   0.0013590069767625609
# Wi: letter1:  b letter2:  a   0.07612806145682777
# Wi: letter1:  v letter2:  m   0.0
# Wi: letter1:  v letter2:  n   2.8663150653519834e-05
# Wi: letter1:  v letter2:  o   0.052969502407704656
# Wi: letter1:  v letter2:  p   5.732630130703967e-05
# Wi: letter1:  v letter2:  q   0.0
# Wi: letter1:  v letter2:  r   0.00014331575326759918
# Wi: letter1:  v letter2:  s   0.0
# Wi: letter1:  v letter2:  t   2.8663150653519834e-05
# Wi: letter1:  v letter2:  u   0.0014618206833295116
# Wi: letter1:  v letter2:  v   2.8663150653519834e-05
# Wi: letter1:  v letter2:  w   0.0
# Wi: letter1:  v letter2:  x   0.0
# Wi: letter1:  v letter2:  y   0.0030382939692731024
# Wi: letter1:  v letter2:  z   0.0
# Wi: letter1:  w letter2:  a   0.22314004771889234
# Wi: letter1:  w letter2:  b   0.000542260140264623
# Wi: letter1:  w letter2:  c   0.00023497939411466995
# Wi: letter1:  w letter2:  d   0.0025486226592437277
# Wi: letter1:  w letter2:  e   0.17119152628154147
# Wi: letter1:  w letter2:  f   0.0004518834502205191
# Wi: letter1:  w letter2:  g   3.615067601764153e-05
# Wi: letter1:  w letter2:  h   0.19271925385004698
# Wi: letter1:  w letter2:  i   0.20287759381100426
# Wi: letter1:  w letter2:  j   0.0
# Wi: letter1:  w letter2:  k   0.0004699587882293399
# Wi: letter1:  w letter2:  l   0.00638059431711373
# Wi: letter1:  w letter2:  m   0.00041573277420287757
# Wi: letter1:  w letter2:  n   0.04307353047501988
# Wi: letter1:  w letter2:  o   0.11826693659171426
# Wi: letter1:  w letter2:  p   0.00041573277420287757
# Wi: letter1:  w letter2:  q   0.0
# Wi: letter1:  w letter2:  r   0.01700889306630034
# Wi: letter1:  w letter2:  s   0.01561709203962114
# Wi: letter1:  w letter2:  t   0.0029824307714554263
# Wi: letter1:  w letter2:  u   0.000542260140264623
# Wi: letter1:  w letter2:  v   0.0
# Wi: letter1:  w letter2:  w   1.8075338008820764e-05
# Wi: letter1:  w letter2:  x   0.0
# Wi: letter1:  w letter2:  y   0.0010664449425204251
# Wi: letter1:  w letter2:  z   0.0
# Wi: letter1:  x letter2:  a   0.09655606227394245
# Wi: letter1:  x letter2:  b   0.0
# Wi: letter1:  x letter2:  c   0.11589872621481365
# Wi: letter1:  x letter2:  d   0.0
# Wi: letter1:  x letter2:  e   0.07972951721968863
# Wi: letter1:  x letter2:  f   0.0
# Wi: letter1:  x letter2:  g   0.0
# Wi: letter1:  x letter2:  h   0.017455574775908162
# Wi: letter1:  x letter2:  i   0.1335115584211354
# Wi: letter1:  x letter2:  j   0.0
# Wi: letter1:  x letter2:  k   0.0
# Wi: letter1:  x letter2:  l   0.0011008020128951094
# Wi: letter1:  x letter2:  m   0.0
# Wi: letter1:  x letter2:  n   0.00015725743041358704
# Wi: letter1:  x letter2:  o   0.00534675263406196
# Wi: letter1:  x letter2:  p   0.3325994653247366
# Wi: letter1:  x letter2:  q   0.0007862871520679352
# Wi: letter1:  x letter2:  r   0.0
# Wi: letter1:  x letter2:  s   0.0003145148608271741
# Wi: letter1:  x letter2:  t   0.18729359962258216
